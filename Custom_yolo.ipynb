# %% [markdown]
# <a href="https://colab.research.google.com/github/Abubakar26/Abubakar26/blob/main/Custom_yolo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive
# Out:
# /content/drive

# %%
# %ls
# Out:
# MyDrive/

# %%
# %cd MyDrive
# Out:
# /content/drive/MyDrive

# %%
# %cd yolov3
# Out:
# /content/drive/MyDrive/yolov3

# %%
# %cd Yolo/darknet-master
# Out:
# /content/drive/MyDrive/yolov3/Yolo/darknet-master

# %%
# %ls
# Out:
#  3rdparty/           'darknet (1)'             net_cam_v3.sh*
#  backup/              DarknetConfig.cmake.in   net_cam_v4.sh*
#  bad.list             darknet_images.py        obj/
#  build/               darknet.py               out/
#  build.ps1            darknet_video.py         README.md
#  cfg/                 data/                    results/
#  chart.png            image_yolov3.sh*         scripts/
#  chart_yolo-obj.png   image_yolov4.sh*         src/
#  cmake/               include/                 vcpkg.json
#  CMakeLists.txt       json_mjpeg_streams.sh*   video_yolov3.sh*
#  CMakeSettings.json   LICENSE                  video_yolov4.sh*
#  darknet*             Makefile

# %%
# !make
# Out:
# chmod +x *.sh

# %%
# %cd darknet-master
# Out:
# [Errno 2] No such file or directory: 'darknet-master'
# /content/drive/MyDrive/yolov3/Yolo/darknet-master

# %%
# !chmod +x ./darknet

# %%
# !./darknet detector train ./data/obj.data cfg/yolo-obj.cfg ./data/darknet53.conv.74 -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.615326), count: 13, class_loss = 2.847351, iou_loss = 2.188163, total_loss = 5.035514
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.633969), count: 9, class_loss = 2.749387, iou_loss = 1.194201, total_loss = 3.943588
#  total_bbox = 387456, rewritten_bbox = 0.238737 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.630076), count: 6, class_loss = 1.034453, iou_loss = 0.584954, total_loss = 1.619407
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.586090), count: 17, class_loss = 3.910943, iou_loss = 2.107207, total_loss = 6.018150
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.657028), count: 8, class_loss = 1.870976, iou_loss = 0.911050, total_loss = 2.782027
# ...

# %%
cd /content/drive/MyDrive/yolov3/Yolo/
# Out:
# /content/drive/MyDrive/yolov3/Yolo
